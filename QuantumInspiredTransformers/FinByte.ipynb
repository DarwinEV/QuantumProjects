# %% [markdown]
# # Financial Time Series Prediction with Transformer Model
# ---
#
# ## Import Libraries

# %%
# !pip install ta
# Out:
# Collecting ta
#   Downloading ta-0.11.0.tar.gz (25 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\mehur\anaconda3\envs\pytorch_cuda\lib\site-packages (from ta) (2.0.1)
# Requirement already satisfied: pandas in c:\users\mehur\anaconda3\envs\pytorch_cuda\lib\site-packages (from ta) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mehur\anaconda3\envs\pytorch_cuda\lib\site-packages (from pandas->ta) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mehur\anaconda3\envs\pytorch_cuda\lib\site-packages (from pandas->ta) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mehur\anaconda3\envs\pytorch_cuda\lib\site-packages (from pandas->ta) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\mehur\anaconda3\envs\pytorch_cuda\lib\site-packages (from python-dateutil>=2.8.2->pandas->ta) (1.16.0)
# Building wheels for collected packages: ta
#   Building wheel for ta (setup.py): started
#   Building wheel for ta (setup.py): finished with status 'done'
#   Created wheel for ta: filename=ta-0.11.0-py3-none-any.whl size=29423 sha256=e1d32b699f4571cf035abf067b718d67444f3496cf87aab5212f013d0c743a7d
#   Stored in directory: c:\users\mehur\appdata\local\pip\cache\wheels\5f\67\4f\8a9f252836e053e532c6587a3230bc72a4deb16b03a829610b
# Successfully built ta
# Installing collected packages: ta
# Successfully installed ta-0.11.0

# %%
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.preprocessing import MinMaxScaler
from torch.utils.data import TensorDataset, DataLoader
from sklearn.metrics import mean_squared_error

from torch.optim.lr_scheduler import ReduceLROnPlateau
import copy
import ta

# %%
# Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %% [markdown]
# ## Data Preparation

# %%
# Parameters
ticker = "^GSPC"  # S&P 500
start_date = "1980-01-01"
end_date = "2024-01-01"
sequence_length = 64  # Number of days to use for prediction
train_ratio = 0.7  # Train split ratio
val_ratio = 0.15  # Validation split ratio
test_ratio = 0.15  # Test split ratio

# %%
def load_financial_data(ticker, start_date, end_date):
    data = yf.download(ticker, start=start_date, end=end_date)
    prices = data['Close'].values
    volume = data['Volume'].values
    dates = data.index

    return prices, volume, dates

def preprocess_data(prices, volume, sequence_length, train_ratio=0.7, val_ratio=0.15):
    # Stack prices, volume, and other indicators as features
    data = np.column_stack((prices, volume))
    
    scaler = MinMaxScaler(feature_range=(0, 1))
    normalized_data = scaler.fit_transform(data)

    # Create sequences
    input_sequences = []
    output_sequences = []
    for i in range(len(normalized_data) - sequence_length):
        input_sequences.append(normalized_data[i:i + sequence_length])
        output_sequences.append(normalized_data[i + sequence_length, 0])  # Predicting price

    input_sequences = np.array(input_sequences)
    output_sequences = np.array(output_sequences)

    # Split into train, val, and test sets
    total_size = len(input_sequences)
    train_size = int(total_size * train_ratio)
    val_size = int(total_size * val_ratio)
    test_size = total_size - train_size - val_size

    train_inputs = input_sequences[:train_size]
    train_outputs = output_sequences[:train_size]
    val_inputs = input_sequences[train_size:train_size + val_size]
    val_outputs = output_sequences[train_size:train_size + val_size]
    test_inputs = input_sequences[train_size + val_size:]
    test_outputs = output_sequences[train_size + val_size:]

    # Convert to PyTorch tensors and move to the selected device
    train_inputs = torch.from_numpy(train_inputs).float().to(device)
    train_outputs = torch.from_numpy(train_outputs).float().to(device)
    val_inputs = torch.from_numpy(val_inputs).float().to(device)
    val_outputs = torch.from_numpy(val_outputs).float().to(device)
    test_inputs = torch.from_numpy(test_inputs).float().to(device)
    test_outputs = torch.from_numpy(test_outputs).float().to(device)

    return train_inputs, train_outputs, val_inputs, val_outputs, test_inputs, test_outputs, scaler

# %%
# Load and preprocess data 
prices, volume, dates = load_financial_data(ticker, start_date, end_date)
train_inputs, train_outputs, val_inputs, val_outputs, test_inputs, test_outputs, scaler = preprocess_data(prices, volume, sequence_length, train_ratio, val_ratio)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ---
#
# ## Model Definition

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=5000):
        super(PositionalEncoding, self).__init__()
        # Compute the positional encodings once in log space.
        pe = torch.zeros(max_len, d_model).to(device)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1).to(device)
        div_term = torch.exp(torch.arange(0, d_model, 2).float().to(device) * (-np.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        if d_model % 2 == 1:
            pe[:, 1::2] = torch.cos(position * div_term)[:,:-1]
        else:
            pe[:, 1::2] = torch.cos(position * div_term)
        self.pe = pe.unsqueeze(0)

    def forward(self, x):
        # x: (batch_size, seq_len, d_model)
        x = x + self.pe[:, :x.size(1), :]
        return x

class TransformerTimeSeries(nn.Module):
    def __init__(self, input_dim=2, d_model=1024, nhead=4, num_layers=1, dim_feedforward=4096, dropout=0.2):
        super(TransformerTimeSeries, self).__init__()
        self.input_projection = nn.Linear(input_dim, d_model)
        self.positional_encoding = PositionalEncoding(d_model)
        encoder_layer = nn.TransformerEncoderLayer(d_model=d_model, nhead=nhead, dim_feedforward=dim_feedforward, dropout=dropout)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
        self.decoder = nn.Linear(d_model, 1)

    def forward(self, src):
        # src shape: (batch_size, seq_len, input_dim)
        src = self.input_projection(src)  # (batch_size, seq_len, d_model)
        src = self.positional_encoding(src)  # Add positional encoding
        src = src.permute(1, 0, 2)  # (seq_len, batch_size, d_model)
        output = self.transformer_encoder(src)
        output = output[-1, :, :]  # Use the output from the last time step
        output = self.decoder(output)
        return output.squeeze()

# %% [markdown]
# ---
#
# ## Training the Model

# %%
def custom_loss(outputs, targets):
    epsilon = 1e-8
    # Compute percentage changes using tensor slicing (do not detach)
    pred_pct_change = (outputs[1:] - outputs[:-1]) / (targets[:-1] + epsilon) * 100
    actual_pct_change = (targets[1:] - targets[:-1]) / (targets[:-1] + epsilon) * 100

    # Mean Squared Error for raw prices
    mse_price = nn.MSELoss()(outputs, targets)

    # Mean Squared Error for percentage changes
    mse_pct_change = nn.MSELoss()(pred_pct_change, actual_pct_change)

    # Combine the losses, with a smaller weight on the percentage change loss
    return mse_price + 0.0000000 * mse_pct_change

# %%
def train_model(model, train_inputs, train_outputs, val_inputs, val_outputs, epochs=50, batch_size=64, lr=0.001, patience=10):
    train_dataset = TensorDataset(train_inputs, train_outputs)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

    val_dataset = TensorDataset(val_inputs, val_outputs)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    criterion = custom_loss
    optimizer = optim.Adam(model.parameters(), lr=lr)
    scheduler = ReduceLROnPlateau(optimizer, 'min', patience=5, factor=0.5, verbose=True)

    best_val_loss = float('inf')
    best_model_wts = copy.deepcopy(model.state_dict())
    epochs_no_improve = 0

    for epoch in range(epochs):
        model.train()
        total_train_loss = 0
        for batch_inputs, batch_targets in train_loader:
            optimizer.zero_grad()
            outputs = model(batch_inputs)
            loss = criterion(outputs, batch_targets)
            loss.backward()
            optimizer.step()
            total_train_loss += loss.item() * batch_inputs.size(0)

        avg_train_loss = total_train_loss / len(train_loader.dataset)

        model.eval()
        total_val_loss = 0
        with torch.no_grad():
            for val_inputs_batch, val_targets_batch in val_loader:
                val_outputs_batch = model(val_inputs_batch)
                val_loss = criterion(val_outputs_batch, val_targets_batch)
                total_val_loss += val_loss.item() * val_inputs_batch.size(0)

        avg_val_loss = total_val_loss / len(val_loader.dataset)
        scheduler.step(avg_val_loss)

        print(f"Epoch {epoch + 1}/{epochs}, Train Loss: {avg_train_loss:.6f}, Val Loss: {avg_val_loss:.6f}")

        # Early stopping
        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            best_model_wts = copy.deepcopy(model.state_dict())
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1
            if epochs_no_improve >= patience:
                print("Early stopping!")
                break

    # Load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
# Initialize and move the model to the selected device
model = TransformerTimeSeries().to(device)
epochs = 100
batch_size = 64
learning_rate = 0.001
patience = 10  # For early stopping

model = train_model(model, train_inputs, train_outputs, val_inputs, val_outputs, epochs=epochs, batch_size=batch_size, lr=learning_rate, patience=patience)
# Out:
# C:\Users\mehur\anaconda3\envs\pytorch_cuda\lib\site-packages\torch\nn\modules\transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# C:\Users\mehur\anaconda3\envs\pytorch_cuda\lib\site-packages\torch\optim\lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1/100, Train Loss: 2.215204, Val Loss: 0.049860
# Epoch 2/100, Train Loss: 0.016504, Val Loss: 0.053081
# Epoch 3/100, Train Loss: 0.014195, Val Loss: 0.036469
# Epoch 4/100, Train Loss: 0.012841, Val Loss: 0.044174
# Epoch 5/100, Train Loss: 0.010897, Val Loss: 0.034079
# Epoch 6/100, Train Loss: 0.008895, Val Loss: 0.017222
# Epoch 7/100, Train Loss: 0.005106, Val Loss: 0.008614
# Epoch 8/100, Train Loss: 0.003679, Val Loss: 0.007380
# Epoch 9/100, Train Loss: 0.003024, Val Loss: 0.007096
# Epoch 10/100, Train Loss: 0.002539, Val Loss: 0.003312
# Epoch 11/100, Train Loss: 0.002038, Val Loss: 0.003129
# Epoch 12/100, Train Loss: 0.001650, Val Loss: 0.002426
# Epoch 13/100, Train Loss: 0.001477, Val Loss: 0.001555
# Epoch 14/100, Train Loss: 0.001150, Val Loss: 0.001944
# Epoch 15/100, Train Loss: 0.000916, Val Loss: 0.001153
# Epoch 16/100, Train Loss: 0.000904, Val Loss: 0.001060
# Epoch 17/100, Train Loss: 0.000794, Val Loss: 0.001028
# Epoch 18/100, Train Loss: 0.000773, Val Loss: 0.001050
# Epoch 19/100, Train Loss: 0.000660, Val Loss: 0.001043
# Epoch 20/100, Train Loss: 0.000618, Val Loss: 0.001099
# Epoch 21/100, Train Loss: 0.000693, Val Loss: 0.000799
# Epoch 22/100, Train Loss: 0.000585, Val Loss: 0.001401
# Epoch 23/100, Train Loss: 0.000663, Val Loss: 0.000932
# Epoch 24/100, Train Loss: 0.000587, Val Loss: 0.001011
# Epoch 25/100, Train Loss: 0.000486, Val Loss: 0.000918
# Epoch 26/100, Train Loss: 0.000467, Val Loss: 0.001196
# Epoch 27/100, Train Loss: 0.000512, Val Loss: 0.001274
# Epoch 28/100, Train Loss: 0.000369, Val Loss: 0.000818
# Epoch 29/100, Train Loss: 0.000330, Val Loss: 0.000770
# Epoch 30/100, Train Loss: 0.000343, Val Loss: 0.000880
# Epoch 31/100, Train Loss: 0.000289, Val Loss: 0.000792
# Epoch 32/100, Train Loss: 0.000314, Val Loss: 0.000888
# Epoch 33/100, Train Loss: 0.000259, Val Loss: 0.001130
# Epoch 34/100, Train Loss: 0.000317, Val Loss: 0.000790
# Epoch 35/100, Train Loss: 0.000294, Val Loss: 0.001126
# Epoch 36/100, Train Loss: 0.000226, Val Loss: 0.000874
# Epoch 37/100, Train Loss: 0.000259, Val Loss: 0.000742
# Epoch 38/100, Train Loss: 0.000217, Val Loss: 0.000716
# Epoch 39/100, Train Loss: 0.000220, Val Loss: 0.000538
# Epoch 40/100, Train Loss: 0.000212, Val Loss: 0.000584
# Epoch 41/100, Train Loss: 0.000200, Val Loss: 0.000765
# Epoch 42/100, Train Loss: 0.000194, Val Loss: 0.001076
# Epoch 43/100, Train Loss: 0.000206, Val Loss: 0.001280
# Epoch 44/100, Train Loss: 0.000198, Val Loss: 0.000719
# Epoch 45/100, Train Loss: 0.000193, Val Loss: 0.000943
# Epoch 46/100, Train Loss: 0.000167, Val Loss: 0.000727
# Epoch 47/100, Train Loss: 0.000174, Val Loss: 0.000789
# Epoch 48/100, Train Loss: 0.000165, Val Loss: 0.000798
# Epoch 49/100, Train Loss: 0.000165, Val Loss: 0.000625
# Early stopping!

# %% [markdown]
# ---
#
# ## Evaluating the model

# %%
torch.cuda.memory_summary()
# Out:
# '|===========================================================================|\n|                  PyTorch CUDA memory summary, device ID 0                 |\n|---------------------------------------------------------------------------|\n|            CUDA OOMs: 0            |        cudaMalloc retries: 0         |\n|===========================================================================|\n|        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |\n|---------------------------------------------------------------------------|\n| Allocated memory      | 141227 KiB |   8377 MiB |  33133 GiB |  33133 GiB |\n|       from large pool | 139392 KiB |   8376 MiB |  33033 GiB |  33033 GiB |\n|       from small pool |   1835 KiB |      6 MiB |    100 GiB |    100 GiB |\n|---------------------------------------------------------------------------|\n| Active memory         | 141227 KiB |   8377 MiB |  33133 GiB |  33133 GiB |\n|       from large pool | 139392 KiB |   8376 MiB |  33033 GiB |  33033 GiB |\n|       from small pool |   1835 KiB |      6 MiB |    100 GiB |    100 GiB |\n|---------------------------------------------------------------------------|\n| Requested memory      | 140637 KiB |   8375 MiB |  33129 GiB |  33129 GiB |\n|       from large pool | 138804 KiB |   8375 MiB |  33029 GiB |  33029 GiB |\n|       from small pool |   1833 KiB |      6 MiB |    100 GiB |    100 GiB |\n|---------------------------------------------------------------------------|\n| GPU reserved memory   |  20604 MiB |  20604 MiB |  20604 MiB |      0 B   |\n|       from large pool |  20596 MiB |  20596 MiB |  20596 MiB |      0 B   |\n|       from small pool |      8 MiB |      8 MiB |      8 MiB |      0 B   |\n|---------------------------------------------------------------------------|\n| Non-releasable memory | 235605 KiB |   5046 MiB |  31250 GiB |  31250 GiB |\n|       from large pool | 233344 KiB |   5044 MiB |  31146 GiB |  31146 GiB |\n|       from small pool |   2261 KiB |      3 MiB |    104 GiB |    104 GiB |\n|---------------------------------------------------------------------------|\n| Allocations           |      41    |     115    |    2205 K  |    2205 K  |\n|       from large pool |      12    |      38    |    1042 K  |    1042 K  |\n|       from small pool |      29    |      90    |    1163 K  |    1163 K  |\n|---------------------------------------------------------------------------|\n| Active allocs         |      41    |     115    |    2205 K  |    2205 K  |\n|       from large pool |      12    |      38    |    1042 K  |    1042 K  |\n|       from small pool |      29    |      90    |    1163 K  |    1163 K  |\n|---------------------------------------------------------------------------|\n| GPU reserved segments |      29    |      29    |      29    |       0    |\n|       from large pool |      25    |      25    |      25    |       0    |\n|       from small pool |       4    |       4    |       4    |       0    |\n|---------------------------------------------------------------------------|\n| Non-releasable allocs |      22    |      30    |    1191 K  |    1191 K  |\n|       from large pool |       9    |      17    |     606 K  |     606 K  |\n|       from small pool |      13    |      18    |     585 K  |     585 K  |\n|---------------------------------------------------------------------------|\n| Oversize allocations  |       0    |       0    |       0    |       0    |\n|---------------------------------------------------------------------------|\n| Oversize GPU segments |       0    |       0    |       0    |       0    |\n|===========================================================================|\n'

# %%
# Evaluation on test set
model.eval()
with torch.no_grad():
    test_predictions = model(test_inputs).cpu().numpy()

# Prepare an array with the correct shape for inverse transformation
# Here, we create a placeholder array with the same number of features (9 in this case)
# We replace the first column with our predictions
placeholder = np.zeros((test_predictions.shape[0], train_inputs.shape[2]))
placeholder[:, 0] = test_predictions  # Replace the first column (price) with predictions

# Inverse transform to get actual prices
test_predictions_prices = scaler.inverse_transform(placeholder)[:, 0]
actual_prices = scaler.inverse_transform(np.column_stack((test_outputs.cpu().numpy(), np.zeros((test_outputs.cpu().numpy().shape[0], train_inputs.shape[2] - 1)))))[:, 0]

# Compute percent changes
predicted_pct_changes = np.diff(test_predictions_prices) / test_predictions_prices[:-1] * 100
actual_pct_changes = np.diff(actual_prices) / actual_prices[:-1] * 100

# Compute MSE on percent changes
mse_pct_change = mean_squared_error(actual_pct_changes, predicted_pct_changes)
print(f"MSE on percent changes: {mse_pct_change:.4f}")

# Also compute MSE on prices
mse_prices = mean_squared_error(actual_prices, test_predictions_prices)
print(f"MSE on prices: {mse_prices:.4f}")
# Out:
# MSE on percent changes: 1.6346
# MSE on prices: 1229084.8456

# %% [markdown]
# ---
#
# ## Visualizing the Predictions

# %%
# Plotting the predicted prices vs actual prices

plt.figure(figsize=(12,6))
plt.plot(dates[-len(actual_prices):], actual_prices, label='Actual Prices')
plt.plot(dates[-len(actual_prices):], test_predictions_prices, label='Predicted Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title(f'{ticker} Stock Price Prediction (Price + Volume)')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Plotting the percent changes

plt.figure(figsize=(12,6))
plt.plot(dates[-len(actual_pct_changes):], actual_pct_changes, label='Actual Percent Changes')
plt.plot(dates[-len(predicted_pct_changes):], predicted_pct_changes, label='Predicted Percent Changes')
plt.xlabel('Date')
plt.ylabel('Percent Change (%)')
plt.title(f'{ticker} Stock Price Percent Change Prediction (Price + Volume)')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
def predict_future_prices(model, input_sequence, future_steps, scaler):
    model.eval()
    predictions = []
    input_seq = input_sequence.clone().detach()

    for _ in range(future_steps):
        with torch.no_grad():
            pred = model(input_seq.unsqueeze(0))  # Predict the next price
        predictions.append(pred.item())

        # Create a tensor with the predicted price and placeholders for the other features
        # The number of features should match the original input sequence
        pred_full = torch.zeros_like(input_seq[0]).to(device)  # Create a tensor of zeros with the same shape as a single time step
        pred_full[0] = pred.item()  # Set the predicted price in the first position

        # Update the input sequence by removing the first time step and adding the new prediction
        input_seq = torch.cat((input_seq[1:], pred_full.unsqueeze(0)))  # Append the new time step with the prediction

    # Inverse transform to get actual prices
    predictions = scaler.inverse_transform(np.column_stack((np.array(predictions), np.zeros((len(predictions), input_seq.size(1) - 1)))))[:, 0]
    
    return predictions

# %%
# Predict the next 5 days
future_steps = 5
last_input_sequence = test_inputs[-1]
future_predictions = predict_future_prices(model, last_input_sequence, future_steps, scaler)

print("Future Predictions:")
for i, price in enumerate(future_predictions, 1):
    print(f"Day {i}: ${price:.2f}")

# Create dates for future predictions
last_date = dates[-1]
future_dates = pd.date_range(last_date, periods=future_steps + 1, freq='B')[1:]  # 'B' for business day

plt.figure(figsize=(12,6))
plt.plot(dates[-100:], prices[-100:], label='Historical Prices')
plt.plot(future_dates, future_predictions, label='Future Predictions', marker='o')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title(f'{ticker} Future Stock Price Prediction (Price + Volume)')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Future Predictions:
# Day 1: $2777.88
# Day 2: $2655.42
# Day 3: $2641.61
# Day 4: $2637.76
# Day 5: $2637.75
